# %%
Hardware refers to the physical components of a computer that you can touch, such as the CPU or keyboard. Ex:CPU
Software refers to programs and instructions that run on the hardware, such as the Windows Operating Systems. Ex: Windows OS
